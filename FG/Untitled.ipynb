# %%
from PIL import Image 
import numpy as np
import matplotlib.image as imgr

# %%
#filename = "Linen.jpg"
#with Image.open(filename) as image: 
 #   width, height = image.size 
#Image.size gives a 2-tuple and the width, height can be obtaine

# %%
img = Image.open("Linen.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=925x616 at 0x1FF72A7AB00>

# %%
pix = np.array(img)

# %%
pix.shape
# Out:
# (616, 925, 3)

# %%
pix
# Out:
# array([[[149, 148, 153],
#         [149, 148, 153],
#         [150, 149, 154],
#         ...,
#         [185, 189, 192],
#         [186, 191, 194],
#         [188, 193, 196]],
#
#        [[163, 162, 167],
#         [163, 162, 167],
#         [163, 162, 167],
#         ...,
#         [189, 193, 196],
#         [190, 195, 198],
#         [191, 196, 199]],
#
#        [[171, 170, 175],
#         [170, 169, 174],
#         [169, 168, 173],
#         ...,
#         [191, 195, 198],
#         [192, 197, 200],
#         [192, 197, 200]],
#
#        ...,
#
#        [[110, 106, 107],
#         [107, 103, 104],
#         [103, 101, 102],
#         ...,
#         [172, 171, 166],
#         [125, 124, 119],
#         [130, 131, 126]],
#
#        [[108, 106, 107],
#         [105, 103, 104],
#         [103, 101, 102],
#         ...,
#         [161, 160, 155],
#         [133, 132, 127],
#         [149, 150, 145]],
#
#        [[109, 107, 108],
#         [105, 103, 104],
#         [103, 102, 100],
# ...
